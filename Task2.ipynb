# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
import matplotlib.pyplot as plt
image = Image.open('C:/Users/emre/Desktop/HW1/cat1.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.transpose(method=Image.FLIP_TOP_BOTTOM)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image.jpg')

image = Image.open('C:/Users/emre/Desktop/HW1/cat2.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.transpose(method=Image.FLIP_TOP_BOTTOM)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image2.jpg')

image = Image.open('C:/Users/emre/Desktop/HW1/cat3.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.transpose(method=Image.FLIP_TOP_BOTTOM)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image3.jpg')

image = Image.open('C:/Users/emre/Desktop/HW1/dog1.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.transpose(method=Image.FLIP_TOP_BOTTOM)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image4.jpg')

image = Image.open('C:/Users/emre/Desktop/HW1/cat1.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.transpose(method=Image.FLIP_LEFT_RIGHT)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image5.jpg')

image = Image.open('C:/Users/emre/Desktop/HW1/cat2.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.transpose(method=Image.FLIP_LEFT_RIGHT)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image6.jpg')

image = Image.open('C:/Users/emre/Desktop/HW1/cat3.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.transpose(method=Image.FLIP_LEFT_RIGHT)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image7.jpg')
image = Image.open('C:/Users/emre/Desktop/HW1/dog1.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.transpose(method=Image.FLIP_LEFT_RIGHT)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image8.jpg')

image = Image.open('C:/Users/emre/Desktop/HW1/cat1.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.rotate(90, expand=True)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image9.jpg')
image = Image.open('C:/Users/emre/Desktop/HW1/cat2.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.rotate(90, expand=True)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image10.jpg')
image = Image.open('C:/Users/emre/Desktop/HW1/cat3.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.rotate(90, expand=True)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image11.jpg')
image = Image.open('C:/Users/emre/Desktop/HW1/dog1.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.rotate(90, expand=True)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image12.jpg')

image = Image.open('C:/Users/emre/Desktop/HW1/cat1.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.rotate(-90, expand=True)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image13.jpg')
image = Image.open('C:/Users/emre/Desktop/HW1/cat2.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.rotate(-90, expand=True)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image14.jpg')
image = Image.open('C:/Users/emre/Desktop/HW1/cat3.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.rotate(-90, expand=True)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image15.jpg')
image = Image.open('C:/Users/emre/Desktop/HW1/dog1.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
rotated_image = image.rotate(-90, expand=True)
rotated_image.save('C:/Users/emre/Desktop/HW1/rotated_image16.jpg')

image = Image.open('C:/Users/emre/Desktop/HW1/cat1.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
new_size = (int(image.size[0]/2), int(image.size[1]/2))
resized_image = image.resize(new_size, resample=Image.BICUBIC)
resized_image.save('C:/Users/emre/Desktop/HW1/resized_image.jpg')
image = Image.open('C:/Users/emre/Desktop/HW1/cat2.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
new_size = (int(image.size[0]/2), int(image.size[1]/2))
resized_image = image.resize(new_size, resample=Image.BICUBIC)
resized_image.save('C:/Users/emre/Desktop/HW1/resized_image2.jpg')

image = Image.open('C:/Users/emre/Desktop/HW1/cat3.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
new_size = (int(image.size[0]/2), int(image.size[1]/2))
resized_image = image.resize(new_size, resample=Image.BICUBIC)
resized_image.save('C:/Users/emre/Desktop/HW1/resized_image3.jpg')

image = Image.open('C:/Users/emre/Desktop/HW1/dog1.jpg')
import numpy as np

image_array = np.asarray(image)
plt.imshow(image_array)
plt.show()
new_size = (int(image.size[0]/2), int(image.size[1]/2))
resized_image = image.resize(new_size, resample=Image.BICUBIC)
resized_image.save('C:/Users/emre/Desktop/HW1/resized_image4.jpg')
# Out:
# C:\Users\emre\AppData\Local\Temp\ipykernel_7776\2195040093.py:9: DeprecationWarning: FLIP_TOP_BOTTOM is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.FLIP_TOP_BOTTOM instead.
#   rotated_image = image.transpose(method=Image.FLIP_TOP_BOTTOM)
# C:\Users\emre\AppData\Local\Temp\ipykernel_7776\2195040093.py:18: DeprecationWarning: FLIP_TOP_BOTTOM is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.FLIP_TOP_BOTTOM instead.
#   rotated_image = image.transpose(method=Image.FLIP_TOP_BOTTOM)
# C:\Users\emre\AppData\Local\Temp\ipykernel_7776\2195040093.py:27: DeprecationWarning: FLIP_TOP_BOTTOM is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.FLIP_TOP_BOTTOM instead.
#   rotated_image = image.transpose(method=Image.FLIP_TOP_BOTTOM)
# ...

# %%
image = Image.open('C:/Users/emre/Desktop/HW1/color_template.png')
rgb_data = list(image.getdata())
new_rgb_data = []
for pixel in rgb_data:
    
    new_r = pixel[0] + 50
    new_g = pixel[1] - 30
    new_b = pixel[2] * 1.5
   
    new_rgb_data.append((new_r, new_g, new_b))
